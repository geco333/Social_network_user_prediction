# %% [markdown]
# <h3>Analyzing wireshark pcap file using scapy.</h3>
# <p>> Load the pcap file as a scapy object.</p>
# <p>> Iterate each packet, extract time stamp, size in bytes and the fields from each layer.</p>
# <p>> Convert the packets to a pandas DataFrame.</p>

# %% [markdown]
# <h4>Import required resources.</h4>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scapy.all import *

# %matplotlib inline

# %% [markdown]
# <h4>Setup global variables.</h4>
# <p><b>path: </b>The path to the pcap file to use.</p>
# <p><b>pcap: </b>Use rdpcap() to load the pcap file in to <i>Scapy</i></p>

# %%
path = './facebook.com_clean.pcapng'
pcap = rdpcap(path)

__ = list()

# %% [markdown]
# <h4>Iterate the <i>Scapy</i> pcap data.</h4>
# <p>Create a <i>dict</i> from each <i>scapy</i> layer.</p>
# <p>Each layer field will be a column in the subsequent <i>pandas DataFrame.</i></p>
# <p>Each packet will be a row.</p>

# %%
for packet in pcap:
  _ = dict()

  _['timestamp'] = packet.time - pcap[0].time

  # If the packet has an Ether layer add the
  # src the dst column to the dict,
  # src and dst will be maped to 'www.facebook.com'
  # and 'Client host' based on their MAC.
  if packet.haslayer(scapy.layers.l2.Ether):
    for field in list(packet['Ether'].fields.items()):
      if field[0] == 'src':
        if field[1] == 'a0:ab:1b:59:28:e6':
            _['src'] = 'facebook.com'
            _['dst'] = 'Client host'
        elif field[1] == 'e0:94:67:c5:af:21':
            _['src'] = 'Client host'
            _['dst'] = 'facebook.com'
      else:
            _['Ether.' + field[0]] = field[1]

  # If the packet has an IP layer add all
  # IP data: address, option, flags...
  if packet.haslayer(scapy.layers.inet.IP):
    for field in list(packet['IP'].fields.items()):
      if field[0] == 'options':
        for option in field[1]:
          _['IP.options.' + option[0]] = option[1]
      elif field[0] == 'flags':
        _['IP.' + field[0]] = field[1].flagrepr()
      else:
        _['IP.' + field[0]] = field[1]

  # If the packet has a TCP layer add all
  # TCP data: address, option, flags...
  # Adjust sequence and ack numbers
  # to show relative numbers.
  if packet.haslayer(scapy.layers.inet.TCP):
    for field in list(packet['TCP'].fields.items()):
      if field[0] == 'options':
        for option in field[1]:
          _['TCP.options.' + option[0]] = option[1]
      elif field[0] == 'flags':
        _['TCP.' + field[0]] = field[1].flagrepr()
      elif field[0] == 'seq':
        if packet['IP'].src == '192.168.1.6':
          _['TCP.' + field[0]] = field[1] - 2357798585
        elif packet['IP'].src == '157.240.1.35':
          _['TCP.' + field[0]] = field[1] - 3619121408
      elif field[0] == 'ack':
        if packet['IP'].src == '192.168.1.6':
            if 'S' in packet['TCP'].flags.flagrepr():
              _['TCP.' + field[0]] = 0
            else:
              _['TCP.' + field[0]] = field[1] - 3619121408
        elif packet['IP'].src == '157.240.1.35':
          _['TCP.' + field[0]] = field[1] - 2357798585
      else:
        _['TCP.' + field[0]] = field[1]

  # If the packet has a Raw layer add
  # Raw data and size.
  if packet.haslayer(scapy.packet.Raw):
    _['Raw.load'] = packet['Raw'].load
    _['Raw.load.size'] = len(packet['Raw'].load)
  else:
    _['Raw.load.size'] = 0

  __.append(_)

# %% [markdown]
# <h3>Data table</h3>
# <p>A table summarizing the pandas DataFrame</p>
# <p>sorted by timestamp, the table shows the progress of ack numbers and squence numbers to and from the web site.</p>

# %%
pcap_df = pd.DataFrame(__).sort_values('timestamp')
pcap_df[['timestamp', 'src', 'dst', 'TCP.flags', 'TCP.ack', 'TCP.seq', 'Raw.load.size']]
# Out:
#      timestamp           src           dst TCP.flags  TCP.ack  TCP.seq  \
# 0     0.000000   Client host  facebook.com         S        0        0
# 353   0.000000   Client host  facebook.com         S        0        0
# 354   0.745780  facebook.com   Client host        SA        1        0
# 1     0.745780  facebook.com   Client host        SA        1        0
# 2     0.745853   Client host  facebook.com         A        1        1
# 355   0.745853   Client host  facebook.com         A        1        1
# 3     0.746624   Client host  facebook.com        PA        1        1
# 356   0.746624   Client host  facebook.com        PA        1        1
# 4     2.009379  facebook.com   Client host         A      518        1
# 357   2.009379  facebook.com   Client host         A      518        1
# 358   2.012685  facebook.com   Client host         A      518        1
# 5     2.012685  facebook.com   Client host         A      518        1
# 359   2.020475  facebook.com   Client host         A      518     1401
# 6     2.020475  facebook.com   Client host         A      518     1401
# 360   2.020477  facebook.com   Client host        PA      518     2801
# 7     2.020477  facebook.com   Client host        PA      518     2801
# 361   2.020551   Client host  facebook.com         A     3141      518
# 8     2.020551   Client host  facebook.com         A     3141      518
# 362   2.028343   Client host  facebook.com        PA     3141      518
# 9     2.028343   Client host  facebook.com        PA     3141      518
# 363   2.028584   Client host  facebook.com        PA     3141      582
# 10    2.028584   Client host  facebook.com        PA     3141      582
# 364   2.028797   Client host  facebook.com        PA     3141      668
# 11    2.028797   Client host  facebook.com        PA     3141      668
# 12    2.489321  facebook.com   Client host         A      668     3141
# 365   2.489321  facebook.com   Client host         A      668     3141
# 367   2.491374  facebook.com   Client host        PA      668     3312
# 13    2.491374  facebook.com   Client host        PA      668     3141
# 14    2.491374  facebook.com   Client host        PA      668     3312
# 366   2.491374  facebook.com   Client host        PA      668     3141
# ..         ...           ...           ...       ...      ...      ...
# 691  13.699468   Client host  facebook.com         A   203353    11859
# 338  13.699468   Client host  facebook.com         A   203353    11859
# 339  13.702116  facebook.com   Client host        PA    11859   203353
# 692  13.702116  facebook.com   Client host        PA    11859   203353
# 693  13.706500  facebook.com   Client host        PA    11859   203385
# 340  13.706500  facebook.com   Client host        PA    11859   203385
# 694  13.706554   Client host  facebook.com         A   204619    11859
# 341  13.706554   Client host  facebook.com         A   204619    11859
# 695  13.706705  facebook.com   Client host        PA    11859   204619
# 342  13.706705  facebook.com   Client host        PA    11859   204619
# 696  13.746509   Client host  facebook.com         A   205849    11859
# 343  13.746509   Client host  facebook.com         A   205849    11859
# 697  13.888711  facebook.com   Client host        PA    11859   205849
# 344  13.888711  facebook.com   Client host        PA    11859   205849
# 698  13.891281  facebook.com   Client host        PA    11859   206967
# 345  13.891281  facebook.com   Client host        PA    11859   206967
# 699  13.891502   Client host  facebook.com         A   208228    11859
# 346  13.891502   Client host  facebook.com         A   208228    11859
# 347  13.907360  facebook.com   Client host         A    11859   208228
# 700  13.907360  facebook.com   Client host         A    11859   208228
# 701  13.918352  facebook.com   Client host         A    11859   209628
# 348  13.918352  facebook.com   Client host         A    11859   209628
# 702  13.918405   Client host  facebook.com         A   211028    11859
# 349  13.918405   Client host  facebook.com         A   211028    11859
# 703  13.920825  facebook.com   Client host         A    11859   211028
# 350  13.920825  facebook.com   Client host         A    11859   211028
# 704  13.920826  facebook.com   Client host        PA    11859   212428
# 351  13.920826  facebook.com   Client host        PA    11859   212428
# 352  13.920974   Client host  facebook.com         A   213069    11859
# 705  13.920974   Client host  facebook.com         A   213069    11859
#
#      Raw.load.size
# 0                0
# 353              0
# 354              0
# 1                0
# 2                0
# 355              0
# 3              517
# 356            517
# 4                0
# 357              0
# 358           1400
# 5             1400
# 359           1400
# 6             1400
# 360            340
# 7              340
# 361              0
# 8                0
# 362             64
# 9               64
# 363             86
# 10              86
# 364            501
# 11             501
# 12               0
# 365              0
# 367             74
# 13             171
# 14              74
# 366            171
# ..             ...
# 691              0
# 338              0
# 339             32
# 692             32
# 693           1234
# 340           1234
# 694              0
# 341              0
# 695           1230
# 342           1230
# 696              0
# 343              0
# 697           1118
# 344           1118
# 698           1261
# 345           1261
# 699              0
# 346              0
# 347           1400
# 700           1400
# 701           1400
# 348           1400
# 702              0
# 349              0
# 703           1400
# 350           1400
# 704            641
# 351            641
# 352              0
# 705              0
#
# [706 rows x 7 columns]

# %% [markdown]
# <h3>facebook.com</h3>
# <p>Plots the sequence numbers as a function of elapsed time.</p>

# %%
x = pcap_df['timestamp'][pcap_df['src'] == 'facebook.com']
y = pcap_df['TCP.seq'][pcap_df['src'] == 'facebook.com']

plt.plot(x, y)
plt.title('www.facebook.com')
plt.xlabel('Time')
plt.ylabel('Sequence number')
# Out:
# Text(0, 0.5, 'Sequence number')

# %% [markdown]
# <h3>Client host</h3>
# <p>Plots the sequence numbers as a function of elapsed time.</p>

# %%
x = pcap_df['timestamp'][pcap_df['src'] == 'Client host']
y = pcap_df['TCP.seq'][pcap_df['src'] == 'Client host']

plt.plot(x, y)
plt.title('Client host')
plt.xlabel('Time')
plt.ylabel('Sequence number')
# Out:
# Text(0, 0.5, 'Sequence number')
